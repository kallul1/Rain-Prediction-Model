# %% [markdown]
# ## Importing Liabraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
df =pd.read_csv("weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df=df.drop(["Evaporation","Sunshine","Cloud9am","Cloud3pm","Location","Date"], axis = 1)
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0     13.4     22.9       0.6           W           44.0          W
# 1      7.4     25.1       0.0         WNW           44.0        NNW
# 2     12.9     25.7       0.0         WSW           46.0          W
# 3      9.2     28.0       0.0          NE           24.0         SE
# 4     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       1007.7       1007.1     16.9     21.8        No           No
# ...

# %%
df=df.dropna(axis = 0)
df.shape
# Out:
# (112925, 17)

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['WindGustDir'] = le.fit_transform(df['WindGustDir'])
df['WindDir9am'] = le.fit_transform(df['WindDir9am'])
df['WindDir3pm'] = le.fit_transform(df['WindDir3pm'])
df['RainToday'] = le.fit_transform(df['RainToday'])
df['RainTomorrow'] = le.fit_transform(df['RainTomorrow'])

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#    WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          14          20.0          24.0         71.0         22.0
# 1          15           4.0          22.0         44.0         25.0
# 2          15          19.0          26.0         38.0         30.0
# 3           0          11.0           9.0         45.0         16.0
# 4           7           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday  RainTomorrow
# ...

# %%
X = df.drop(['RainTomorrow'], axis = 1)
Y = df['RainTomorrow']

# %%
X.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#    WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          14          20.0          24.0         71.0         22.0
# 1          15           4.0          22.0         44.0         25.0
# 2          15          19.0          26.0         38.0         30.0
# 3           0          11.0           9.0         45.0         16.0
# 4           7           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday
# 0       1007.7       1007.1     16.9     21.8          0
# ...

# %%
plt.figure(figsize = (8,8))
sns.scatterplot(x = 'MaxTemp', y='MinTemp', hue = 'RainTomorrow', palette = 'inferno', data=df)
# Out:
# <Axes: xlabel='MaxTemp', ylabel='MinTemp'>

# %%
plt.figure(figsize = (8,8))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=10)

# %% [markdown]
# ## Linear Regression

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
prediction1 = LR.predict(X_test)

# %%
mse = mean_squared_error(y_test,prediction1)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test,prediction1)
r2 = r2_score(y_test,prediction1)

# %%
print("mean squared error: ",mse)
print("root mean squared error: ",rmse)
print("mean absolute error: ",mae)
print("r2 score: ",r2)
# Out:
# mean squared error:  0.1164578893835654
# root mean squared error:  0.34125927003316026
# mean absolute error:  0.25840259383424025
# r2 score:  0.3242922514268246

# %%
new_data = np.array([[17.5,32.3,1.0,13,41.0,1,7,7.0,1.0,90.0,100.0,1010.8,1006.0,17.8,29.7,0]])  # Example input data
prediction = LR.predict(new_data)
print(f"Predicted Rainfall: {prediction1[0]}")
# Out:
# Predicted Rainfall: 0.6015210259696531
# C:\Users\Jeet Gogoi\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Logistic Regression

# %%
LOR = LogisticRegression(solver='liblinear')
LOR.fit(X_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
prediction2 = LOR.predict(X_test)
print(confusion_matrix(y_test,prediction2))
print(classification_report(y_test,prediction2))
print(accuracy_score(y_test,prediction2))
# Out:
# [[16645   941]
#  [ 2568  2431]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.90     17586
#            1       0.72      0.49      0.58      4999
#
#     accuracy                           0.84     22585
#    macro avg       0.79      0.72      0.74     22585
# weighted avg       0.83      0.84      0.83     22585
#
# 0.8446313925171574

# %%
new_data = np.array([[17.5,32.3,1.0,13,41.0,1,7,7.0,20.0,82.0,100.0,1010.8,1006.0,17.8,29.7,0]])  # Example input data
prediction2 = LOR.predict(new_data)
print(f"Predicted Rainfall: {prediction2[0]}")
# Out:
# Predicted Rainfall: 1
# C:\Users\Jeet Gogoi\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
X.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#    WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          14          20.0          24.0         71.0         22.0
# 1          15           4.0          22.0         44.0         25.0
# 2          15          19.0          26.0         38.0         30.0
# 3           0          11.0           9.0         45.0         16.0
# 4           7           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm  RainToday
# 0       1007.7       1007.1     16.9     21.8          0
# ...

# %% [markdown]
# ## DECISION TREE

# %%
Tree = DecisionTreeClassifier()
Tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction3 = Tree.predict(X_test)
print(confusion_matrix(y_test,prediction3))
print(classification_report(y_test,prediction3))
print(accuracy_score(y_test,prediction3))
# Out:
# [[15071  2515]
#  [ 2305  2694]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86     17586
#            1       0.52      0.54      0.53      4999
#
#     accuracy                           0.79     22585
#    macro avg       0.69      0.70      0.69     22585
# weighted avg       0.79      0.79      0.79     22585
#
# 0.786584015939783

# %%
new_data = np.array([[17.5,32.3,1.0,13,41.0,1,7,7.0,20.0,82.0,100.0,1010.8,1006.0,17.8,29.7,0]])  # Example input data
prediction3 = Tree.predict(new_data)
print(f"Predicted Rainfall: {prediction3[0]}")
# Out:
# Predicted Rainfall: 0
# C:\Users\Jeet Gogoi\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## RANDOM FOREST CLASSIFIER

# %%
classifier = RandomForestClassifier(n_estimators = 10, criterion = "entropy")
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
prediction4 = classifier.predict(X_test)
print(confusion_matrix(y_test,prediction4))
print(classification_report(y_test,prediction4))
print(accuracy_score(y_test,prediction4))
# Out:
# [[16751   835]
#  [ 2646  2353]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.91     17586
#            1       0.74      0.47      0.57      4999
#
#     accuracy                           0.85     22585
#    macro avg       0.80      0.71      0.74     22585
# weighted avg       0.84      0.85      0.83     22585
#
# 0.8458711534204117

# %%
new_data = np.array([[17.5,32.3,1.0,13,41.0,1,7,7.0,20.0,82.0,100.0,1010.8,1006.0,17.8,29.7,0]])  # Example input data
prediction4 = classifier.predict(new_data)
print(f"Predicted Rainfall: {prediction4[0]}")
# Out:
# Predicted Rainfall: 0
# C:\Users\Jeet Gogoi\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
